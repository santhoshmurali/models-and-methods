# %%
import numpy as npy
import pandas as pds
import matplotlib.pyplot as plt
import matplotlib
matplotlib.style.use('ggplot')

# %matplotlib inline

# %% [markdown]
# ### Logistic regression using Pandas using Titanic Data

# %%
TitanicTrainData = pds.read_csv("C:/Home/Work/Data Science/Python/PyCharm/2017_Vijadhasami/Data/train.csv")

# %%
TitanicTrainData.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
(TitanicTrainData.loc[:,"Survived"].value_counts()/len(TitanicTrainData))*100
# Out:
# 0    61.616162
# 1    38.383838
# Name: Survived, dtype: float64

# %% [markdown]
# ### Convering all the names to Lowe case

# %%
TitanicTrainData.Name = TitanicTrainData.Name.str.lower()

# %%
TitanicTrainData.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            braund, mr. owen harris    male  22.0      1
# 1  cumings, mrs. john bradley (florence briggs th...  female  38.0      1
# 2                             heikkinen, miss. laina  female  26.0      0
# 3       futrelle, mrs. jacques heath (lily may peel)  female  35.0      1
# 4                           allen, mr. william henry    male  35.0      0
# 5                                   moran, mr. james    male   NaN      0
# ...

# %% [markdown]
# ### Creating a Derived Column to mark if the Passennger is has a dependent travelling with.

# %%
TitanicTrainData["HasDependent"]=0

TitanicTrainData.loc[((TitanicTrainData.loc[:,"SibSp"]>0) | (TitanicTrainData.loc[:,"Parch"]>0)),"HasDependent"] = npy.int0(1)

TitanicTrainData.HasDependent.value_counts()
# Out:
# 0    537
# 1    354
# Name: HasDependent, dtype: int64

# %%
TitanicTrainData.loc[TitanicTrainData.Age.isnull(),:]
# Out:
#      PassengerId  Survived  Pclass  \
# 5              6         0       3
# 17            18         1       2
# 19            20         1       3
# 26            27         0       3
# 28            29         1       3
# 29            30         0       3
# 31            32         1       1
# 32            33         1       3
# 36            37         1       3
# 42            43         0       3
# 45            46         0       3
# 46            47         0       3
# 47            48         1       3
# 48            49         0       3
# 55            56         1       1
# 64            65         0       1
# 65            66         1       3
# 76            77         0       3
# 77            78         0       3
# 82            83         1       3
# 87            88         0       3
# 95            96         0       3
# 101          102         0       3
# 107          108         1       3
# 109          110         1       3
# ...

# %%
TitanicTrainData.Age.plot.hist(bins=10)

# %%
TitanicTrainData['AdjustedAge'] = TitanicTrainData.Age
TitanicTrainData['AdjustedAge'] = (TitanicTrainData['AdjustedAge']%10)*10
TitanicTrainData.AdjustedAge.plot.hist()

# %%
TitanicTrainDataAge = TitanicTrainData

TitanicTrainDataAge["NumberOfDependent"] = TitanicTrainDataAge.SibSp + TitanicTrainDataAge.Parch

# %%
TitanicTrainDataAge = TitanicTrainDataAge.loc[:,["PassengerId","Age","Fare","Embarked","NumberOfDependent"]]

# %%
TitanicTrainDataAge.head(10)
# Out:
#    PassengerId   Age     Fare Embarked  NumberOfDependent
# 0            1  22.0   7.2500        S                  1
# 1            2  38.0  71.2833        C                  1
# 2            3  26.0   7.9250        S                  0
# 3            4  35.0  53.1000        S                  1
# 4            5  35.0   8.0500        S                  0
# 5            6   NaN   8.4583        Q                  0
# 6            7  54.0  51.8625        S                  0
# 7            8   2.0  21.0750        S                  4
# 8            9  27.0  11.1333        S                  2
# 9           10  14.0  30.0708        C                  1

# %%
TitanicTrainDataAge_Prod = TitanicTrainDataAge.loc[TitanicTrainDataAge.Age.isnull(),:]

# %%
TitanicTrainDataAge_Dev = TitanicTrainDataAge.loc[TitanicTrainDataAge.Age.isnull() == False,:]

# %%
k
