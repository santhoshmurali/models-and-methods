# %% [markdown]
# # Assignment Topic: Making Election Predictions
#
# ##### If during the early part of 2014 you had to predict the upcoming Lok Sabha Elections, what would be your predictive model?  (Say you wanted to predict the election outcomes six months before the elections were held)
#
# To solve this problem…here are some possible stuff you can think of….
#
# * Identify data sources. This will depend upon what factors you think can determine winning elections
# * Identifying the right technique/techniques to model that data
# * Make predictions, validate and update your model.
#
# ## Submission details:
#
# ### Part 1:
# #### Identify the data sources, the variables of interest. Process the data and create a ‘clean’ data file(s).
#
# ##### Marks distribution: 20.
#
# #### What needs to be submitted:
#
# * Text file explaining what variables you are choosing and why, the source codes, explanation etc
# * The cleaned data file (s)
# * Relevant r codes if any
#
# Marks will be awarded based on what factors you think are important in model building, what data sources you identify and finally how the clean data looks. The clean data has to be submitted as CSV (files).
#
# ### Part 2:
# #### Develop the model,present a predictive model.
#
# ##### Marks distribution: 20
#
# #### What needs to be submitted:
#
# * Text file explaining the model (s), why did you do what you did, model performance et
# * Relevant R codes if any

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## Part 1
# * Identify the data sources
# * Variables of interest.
# * Process the data and create a ‘clean’ data file(s).

# %% [markdown]
# ### Data Sources
#
# #### use the data from the Website http://eci.nic.in/eci_main1/ElectionStatistics.aspx
# We are using the data from 2009 election results and predecting 2014 Election results, assuming the Prediciton is done 6 months before 2014 election
#
# ##### The Data we took it is
# * GENERAL ELECTION TO LOKSABHA, 2009, http://eci.nic.in/eci_main/StatisticalReports/candidatewise/GE2009.xls
#  * Electors
#  * Candidate Wise results.

# %%
# Importing Data Directly from the website
SrcDataElectors = pd.read_excel("http://eci.nic.in/eci_main/StatisticalReports/candidatewise/GE2009.xls","electors", 
                                skiprows=3)
SrcDataCandidates = pd.read_excel("http://eci.nic.in/eci_main/StatisticalReports/candidatewise/GE2009.xls","Cand_Wise", 
                                skiprows=5)

# %% [markdown]
# ##### The data is from all States. Need to filterout only Uttar Pradesh data for Analysis.

# %%
SrcDataElectors.loc[:,"STATE"].value_counts()
# Out:
# Uttar Pradesh                80
# Maharashtra                  48
# Andhra Pradesh               42
# West Bengal                  42
# Bihar                        40
# Tamil Nadu                   39
# Madhya Pradesh               29
# Karnataka                    28
# Gujarat                      26
# Rajasthan                    25
# Orissa                       21
# Kerala                       20
# Assam                        14
# Jharkhand                    14
# Punjab                       13
# Chattisgarh                  11
# Haryana                      10
# NCT OF Delhi                  7
# Jammu & Kashmir               6
# Uttarakhand                   5
# Himachal Pradesh              4
# Arunachal Pradesh             2
# Goa                           2
# Tripura                       2
# Manipur                       2
# Meghalaya                     2
# Sikkim                        1
# Mizoram                       1
# Chandigarh                    1
# Puducherry                    1
# Lakshadweep                   1
# Dadra & Nagar Haveli          1
# Nagaland                      1
# Daman & Diu                   1
# Andaman & Nicobar Islands     1
# Name: STATE, dtype: int64

# %%
SrcDataCandidates.loc[:,"State name"].value_counts()
# Out:
# Uttar Pradesh                1368
# Tamil Nadu                    823
# Maharashtra                   819
# Bihar                         672
# Andhra Pradesh                569
# Madhya Pradesh                429
# Karnataka                     427
# West Bengal                   368
# Gujarat                       359
# Rajasthan                     346
# Jharkhand                     249
# Punjab                        218
# Kerala                        217
# Haryana                       210
# Chattisgarh                   178
# NCT OF Delhi                  160
# Assam                         158
# Orissa                        157
# Jammu & Kashmir                81
# Uttarakhand                    76
# Himachal Pradesh               31
# Puducherry                     28
# Tripura                        19
# Goa                            18
# Manipur                        16
# Chandigarh                     14
# Andaman & Nicobar Islands      11
# Meghalaya                      11
# Arunachal Pradesh               8
# Sikkim                          7
# Daman & Diu                     7
# Dadra & Nagar Haveli            5
# Lakshadweep                     4
# Mizoram                         4
# Nagaland                        3
# Name: State name, dtype: int64

# %%
#UPCandidates

UPElectors = SrcDataElectors.loc[SrcDataElectors["STATE"] =='Uttar Pradesh',:]
UPCandidates = SrcDataCandidates.loc[SrcDataCandidates["State name"]=='Uttar Pradesh',:]

# %%
UPElectors["STATE"].value_counts()
# Out:
# Uttar Pradesh    80
# Name: STATE, dtype: int64

# %%
UPCandidates["State name"].value_counts()
# Out:
# Uttar Pradesh    1368
# Name: State name, dtype: int64

# %%
UPElectors.columns
# Out:
# Index(['STATE CODE', 'STATE', 'PC NO', 'PARLIAMENTARY CONSTITUENCY',
#        'Total voters', 'Total_Electors', 'TOT_CONTESTANT', 'POLL PERCENTAGE'],
#       dtype='object')

# %%
UPCandidates.columns
# Out:
# Index(['ST_CODE', 'State name', 'Month', 'Year', 'PC Number', 'PC name',
#        'PC Type', 'Candidate Name', 'Candidate Sex', 'Candidate Category',
#        'Candidate Age', 'Party Abbreviation', 'Total Votes Polled',
#        'Position'],
#       dtype='object')

# %% [markdown]
# #### Joining the Candidates and Electors data to get one holistic Data Frame

# %%
temp = pd.merge(UPCandidates, UPElectors, how='outer', left_on='PC Number', right_on='PC NO')

# %%
temp.columns
# Out:
# Index(['ST_CODE', 'State name', 'Month', 'Year', 'PC Number', 'PC name',
#        'PC Type', 'Candidate Name', 'Candidate Sex', 'Candidate Category',
#        'Candidate Age', 'Party Abbreviation', 'Total Votes Polled', 'Position',
#        'STATE CODE', 'STATE', 'PC NO', 'PARLIAMENTARY CONSTITUENCY',
#        'Total voters', 'Total_Electors', 'TOT_CONTESTANT', 'POLL PERCENTAGE'],
#       dtype='object')

# %%
UP2009BASEDATA = temp.loc[:,[ 'STATE CODE', 'State name', 'PC Number', 'PC name',
       'PC Type', 'Candidate Name', 'Candidate Sex', 'Candidate Category',
       'Candidate Age', 'Party Abbreviation', 'Total Votes Polled', 'Position',
       'Total voters', 'Total_Electors', 'TOT_CONTESTANT', 'POLL PERCENTAGE']]

# %%
UP2009BASEDATA
# Out:
#      STATE CODE     State name  PC Number      PC name PC Type  \
# 0           S24  Uttar Pradesh          1   Saharanpur     GEN
# 1           S24  Uttar Pradesh          1   Saharanpur     GEN
# 2           S24  Uttar Pradesh          1   Saharanpur     GEN
# 3           S24  Uttar Pradesh          1   Saharanpur     GEN
# 4           S24  Uttar Pradesh          1   Saharanpur     GEN
# 5           S24  Uttar Pradesh          1   Saharanpur     GEN
# 6           S24  Uttar Pradesh          1   Saharanpur     GEN
# 7           S24  Uttar Pradesh          1   Saharanpur     GEN
# 8           S24  Uttar Pradesh          1   Saharanpur     GEN
# 9           S24  Uttar Pradesh          1   Saharanpur     GEN
# 10          S24  Uttar Pradesh          1   Saharanpur     GEN
# 11          S24  Uttar Pradesh          1   Saharanpur     GEN
# 12          S24  Uttar Pradesh          1   Saharanpur     GEN
# 13          S24  Uttar Pradesh          1   Saharanpur     GEN
# 14          S24  Uttar Pradesh          1   Saharanpur     GEN
# 15          S24  Uttar Pradesh          2      Kairana     GEN
# 16          S24  Uttar Pradesh          2      Kairana     GEN
# 17          S24  Uttar Pradesh          2      Kairana     GEN
# 18          S24  Uttar Pradesh          2      Kairana     GEN
# 19          S24  Uttar Pradesh          2      Kairana     GEN
# 20          S24  Uttar Pradesh          2      Kairana     GEN
# 21          S24  Uttar Pradesh          2      Kairana     GEN
# 22          S24  Uttar Pradesh          2      Kairana     GEN
# 23          S24  Uttar Pradesh          2      Kairana     GEN
# 24          S24  Uttar Pradesh          2      Kairana     GEN
# 25          S24  Uttar Pradesh          2      Kairana     GEN
# 26          S24  Uttar Pradesh          2      Kairana     GEN
# 27          S24  Uttar Pradesh          2      Kairana     GEN
# 28          S24  Uttar Pradesh          2      Kairana     GEN
# 29          S24  Uttar Pradesh          2      Kairana     GEN
# ...         ...            ...        ...          ...     ...
# 1338        S24  Uttar Pradesh         79     Mirzapur     GEN
# 1339        S24  Uttar Pradesh         79     Mirzapur     GEN
# 1340        S24  Uttar Pradesh         79     Mirzapur     GEN
# 1341        S24  Uttar Pradesh         79     Mirzapur     GEN
# 1342        S24  Uttar Pradesh         79     Mirzapur     GEN
# 1343        S24  Uttar Pradesh         79     Mirzapur     GEN
# 1344        S24  Uttar Pradesh         79     Mirzapur     GEN
# 1345        S24  Uttar Pradesh         79     Mirzapur     GEN
# 1346        S24  Uttar Pradesh         79     Mirzapur     GEN
# 1347        S24  Uttar Pradesh         79     Mirzapur     GEN
# 1348        S24  Uttar Pradesh         79     Mirzapur     GEN
# 1349        S24  Uttar Pradesh         79     Mirzapur     GEN
# 1350        S24  Uttar Pradesh         79     Mirzapur     GEN
# 1351        S24  Uttar Pradesh         79     Mirzapur     GEN
# 1352        S24  Uttar Pradesh         79     Mirzapur     GEN
# 1353        S24  Uttar Pradesh         79     Mirzapur     GEN
# 1354        S24  Uttar Pradesh         79     Mirzapur     GEN
# 1355        S24  Uttar Pradesh         79     Mirzapur     GEN
# 1356        S24  Uttar Pradesh         79     Mirzapur     GEN
# 1357        S24  Uttar Pradesh         79     Mirzapur     GEN
# 1358        S24  Uttar Pradesh         80  Robertsganj      SC
# 1359        S24  Uttar Pradesh         80  Robertsganj      SC
# 1360        S24  Uttar Pradesh         80  Robertsganj      SC
# 1361        S24  Uttar Pradesh         80  Robertsganj      SC
# 1362        S24  Uttar Pradesh         80  Robertsganj      SC
# 1363        S24  Uttar Pradesh         80  Robertsganj      SC
# 1364        S24  Uttar Pradesh         80  Robertsganj      SC
# 1365        S24  Uttar Pradesh         80  Robertsganj      SC
# 1366        S24  Uttar Pradesh         80  Robertsganj      SC
# 1367        S24  Uttar Pradesh         80  Robertsganj      SC
#
#                   Candidate Name Candidate Sex Candidate Category  \
# 0             JAGDISH SINGH RANA             M                GEN
# 1                 RASHEED MASOOD             M                GEN
# 2            JASWANT SINGH SAINI             M                GEN
# 3                    GAJAY SINGH             M                GEN
# 4          HAJI MOHAMMED TAUSEEF             M                GEN
# 5                  M.RASHID KHAN             M                GEN
# 6          CHATTAR SINGH KASHYAP             M                GEN
# 7                       MASHKOOR             M                GEN
# 8                     NATHLU RAM             M                 SC
# 9                        TEJVEER             M                GEN
# 10                    CHINTAMANI             M                GEN
# 11                     MOHD.ASIF             M                GEN
# 12                YOGESH GAMBHIR             M                GEN
# 13         CHANDRA PRAKASH ARORA             M                GEN
# 14                  SUSHIL KUMAR             M                 SC
# 15                TABASSUM BEGUM             F                GEN
# 16                   HUKUM SINGH             M                GEN
# 17                 SHAJAN MASOOD             M                GEN
# 18                SURENDRA KUMAR             M                GEN
# 19                        LAKHMI             M                GEN
# 20    ADVOCATE BRAHAM PAL GURJAR             M                GEN
# 21                   MUKTA SINGH             F                GEN
# 22             KARAN SINGH SAINI             M                GEN
# 23                       KULDEEP             M                GEN
# 24                      ABHISHEK             M                GEN
# 25                   RAJ BAHADUR             M                 SC
# 26                   PRIYA KUMAR             M                GEN
# 27                    KUNWAR PAL             M                GEN
# 28                RAJNISH NOTIAL             M                 SC
# 29                        SHAFIK             M                GEN
# ...                          ...           ...                ...
# 1338                 ANOOP KUMAR             M                GEN
# 1339                   SHYAM LAL             M                GEN
# 1340                  HANS KUMAR             M                GEN
# 1341                     SHANKAR             M                 SC
# 1342                 MOHD. SAGIR             M                GEN
# 1343        KRISHNA CHAND SHUKLA             M                GEN
# 1344                AJAY SHANKER             M                 SC
# 1345               KRISHNA CHAND             M                GEN
# 1346                  LALTI DEVI             F                 SC
# 1347                     RAM RAJ             M                GEN
# 1348                   RAM GOPAL             M                GEN
# 1349                 MANIK CHAND             M                 SC
# 1350                 RADHE SHYAM             M                 SC
# 1351                     KHELADI             M                 SC
# 1352                       LALJI             M                GEN
# 1353                      DULARI             F                 SC
# 1354                   CHHABEELE             M                GEN
# 1355                     KAILASH             M                 SC
# 1356                   MUNNA LAL             M                GEN
# 1357                      DANGAR             M                 SC
# 1358                 PAKAURI LAL             M                 SC
# 1359           RAM CHANDRA TYAGI             M                 SC
# 1360                  RAM SHAKAL             M                 SC
# 1361            RAM ADHAR JOSEPH             M                 SC
# 1362                  RAMBRIKSHA             M                 SC
# 1363                       GULAB             M                 SC
# 1364             CHANDRA SHEKHAR             M                 SC
# 1365                RAMESH KUMAR             M                 SC
# 1366                  MUNNI DEVI             F                 SC
# 1367               SHRAWAN KUMAR             M                 SC
#
#       Candidate Age Party Abbreviation  Total Votes Polled  Position  \
# 0                53                BSP              354807         1
# 1                59                 SP              269934         2
# 2                38                BJP               99894         3
# 3                50                INC               62593         4
# 4                45               PECP                9214         5
# 5                45                IND                8096         6
# 6                54               VAJP                4647         7
# 7                49                IND                4433         8
# 8                57                IND                2069         9
# 9                48                IND                1773        10
# 10               60                IND                 912        11
# 11               25                IND                 826        12
# 12               41                 BD                 700        13
# 13               53                IND                 650        14
# 14               34               RSBP                 574        15
# 15               39                BSP              283259         1
# 16               71                BJP              260796         2
# 17               36                 SP              124802         3
# 18               45                INC               37795         4
# 19               53                IND                5707         5
# 20               38                IND                3635         6
# 21               35                IND                2155         7
# 22               40                JSP                1758         8
# 23               32                IND                1228         9
# 24               25                IND                1052        10
# 25               26                IJP                 814        11
# 26               37               ABHM                 787        12
# 27               50               RDMP                 604        13
# 28               28                ASP                 486        14
# 29               52               UNLP                 457        15
# ...             ...                ...                 ...       ...
# 1338             34                IND                9127         8
# 1339             41               EKSP                6944         9
# 1340             37                IND                6485        10
# 1341             38         CPI(ML)(L)                5895        11
# 1342             41                NLP                5371        12
# 1343             40                IND                2658        13
# 1344             33                GMS                2441        14
# 1345             40                IND                2402        15
# 1346             54                 VP                2198        16
# 1347             37                IND                1797        17
# 1348             53                IND                1776        18
# 1349             37                IND                1654        19
# 1350             58               BRPP                1650        20
# 1351             58                GGP                1605        21
# 1352             48                RAD                1560        22
# 1353             61                IND                1462        23
# 1354             41                IND                1346        24
# 1355             48                BSA                1316        25
# 1356             34                IND                1189        26
# 1357             52                IND                1078        27
# 1358             57                 SP              216478         1
# 1359             54                BSP              166219         2
# 1360             47                BJP              104411         3
# 1361             43                INC               55809         4
# 1362             39                IND               15936         5
# 1363             31               PDFO                9951         6
# 1364             34                JPS                8439         7
# 1365             31                 AD                8271         8
# 1366             42               RSMD                5445         9
# 1367             41                RWS                4358        10
#
#       Total voters  Total_Electors  TOT_CONTESTANT  POLL PERCENTAGE
# 0           821122         1298132              15        63.254122
# 1           821122         1298132              15        63.254122
# 2           821122         1298132              15        63.254122
# 3           821122         1298132              15        63.254122
# 4           821122         1298132              15        63.254122
# 5           821122         1298132              15        63.254122
# 6           821122         1298132              15        63.254122
# 7           821122         1298132              15        63.254122
# 8           821122         1298132              15        63.254122
# 9           821122         1298132              15        63.254122
# 10          821122         1298132              15        63.254122
# 11          821122         1298132              15        63.254122
# 12          821122         1298132              15        63.254122
# 13          821122         1298132              15        63.254122
# 14          821122         1298132              15        63.254122
# 15          725758         1282551              15        56.587067
# 16          725758         1282551              15        56.587067
# 17          725758         1282551              15        56.587067
# 18          725758         1282551              15        56.587067
# 19          725758         1282551              15        56.587067
# 20          725758         1282551              15        56.587067
# 21          725758         1282551              15        56.587067
# 22          725758         1282551              15        56.587067
# 23          725758         1282551              15        56.587067
# 24          725758         1282551              15        56.587067
# 25          725758         1282551              15        56.587067
# 26          725758         1282551              15        56.587067
# 27          725758         1282551              15        56.587067
# 28          725758         1282551              15        56.587067
# 29          725758         1282551              15        56.587067
# ...            ...             ...             ...              ...
# 1338        733350         1405539              27        52.175713
# 1339        733350         1405539              27        52.175713
# 1340        733350         1405539              27        52.175713
# 1341        733350         1405539              27        52.175713
# 1342        733350         1405539              27        52.175713
# 1343        733350         1405539              27        52.175713
# 1344        733350         1405539              27        52.175713
# 1345        733350         1405539              27        52.175713
# 1346        733350         1405539              27        52.175713
# 1347        733350         1405539              27        52.175713
# 1348        733350         1405539              27        52.175713
# 1349        733350         1405539              27        52.175713
# 1350        733350         1405539              27        52.175713
# 1351        733350         1405539              27        52.175713
# 1352        733350         1405539              27        52.175713
# 1353        733350         1405539              27        52.175713
# 1354        733350         1405539              27        52.175713
# 1355        733350         1405539              27        52.175713
# 1356        733350         1405539              27        52.175713
# 1357        733350         1405539              27        52.175713
# 1358        598810         1214735              10        49.295525
# 1359        598810         1214735              10        49.295525
# 1360        598810         1214735              10        49.295525
# 1361        598810         1214735              10        49.295525
# 1362        598810         1214735              10        49.295525
# 1363        598810         1214735              10        49.295525
# 1364        598810         1214735              10        49.295525
# 1365        598810         1214735              10        49.295525
# 1366        598810         1214735              10        49.295525
# 1367        598810         1214735              10        49.295525
#
# [1368 rows x 16 columns]

# %%
UP2009BASEDATAWINNERS = UP2009BASEDATA.loc[UP2009BASEDATA.Position == 1,:]

# %%
UP2009BASEDATAWINNERS = UP2009BASEDATAWINNERS.loc[:,['STATE CODE','PC Number','Candidate Name','Party Abbreviation','Total_Electors','POLL PERCENTAGE']]

# %%
UP2009BASEDATAWINNERS.columns = ['STATE_CODE 09','PC Number 09','Winning Candidate 09','Winning Party 09','Total_Electors 09','Winning Poll Percentage 09']
UP2009BASEDATAWINNERS
# Out:
#      STATE_CODE 09  PC Number 09                     Winning Candidate 09  \
# 0              S24             1                       JAGDISH SINGH RANA
# 15             S24             2                           TABASSUM BEGUM
# 30             S24             3                               KADIR RANA
# 53             S24             4                     SANJAY SINGH CHAUHAN
# 76             S24             5                            YASHVIR SINGH
# 90             S24             6                      MOHAMMED AZHARUDDIN
# 108            S24             7                        JAYA PRADA NAHATA
# 124            S24             8                 DR. SHAFIQUR RAHMAN BARQ
# 135            S24             9                          DEVENDRA NAGPAL
# 155            S24            10                         RAJENDRA AGARWAL
# 184            S24            11                               AJIT SINGH
# 200            S24            12                            RAJNATH SINGH
# 216            S24            13                     SURENDRA SINGH NAGAR
# 242            S24            14                                  KAMLESH
# 258            S24            15                       RAJ KUMARI CHAUHAN
# 281            S24            16                             SARIKA SINGH
# 291            S24            17                         JAYANT CHAUDHARY
# 307            S24            18                           DR. RAMSHANKAR
# 322            S24            19                           SEEMA UPADHYAY
# 336            S24            20                           AKHILESH YADAV
# 352            S24            21                      MULAYAM SINGH YADAV
# 367            S24            22                 KALYAN SINGH R O MADHOLI
# 386            S24            23                         DHARMENDRA YADAV
# 396            S24            24                             MENKA GANDHI
# 409            S24            25                       PRAVEEN SINGH ARON
# 417            S24            26                      FEROZE VARUN GANDHI
# 433            S24            27                                 MITHLESH
# 448            S24            28                          ZAFAR ALI NAQVI
# 460            S24            29                      KUNWAR JITIN PRASAD
# 472            S24            30                             KAISAR JAHAN
# ...            ...           ...                                      ...
# 825            S24            51                     KAPIL MUNI KARWARIYA
# 849            S24            52  KUNWAR REWATI RAMAN SINGH ALIAS MANI JI
# 880            S24            53                                P.L.PUNIA
# 895            S24            54                            NIRMAL KHATRI
# 918            S24            55                            RAKESH PANDEY
# 940            S24            56                             KAMAL KISHOR
# 953            S24            57                 BRIJBHUSHAN SHARAN SINGH
# 976            S24            58                  VINAY KUMAR ALIAS VINNU
# 987            S24            59                        BENI PRASAD VERMA
# 1012           S24            60                           JAGDAMBIKA PAL
# 1028           S24            61                   ARVIND KUMAR CHAUDHARY
# 1044           S24            62       BHISMA SHANKAR ALIAS KUSHAL TIWARI
# 1068           S24            63                            HARSH VARDHAN
# 1083           S24            64                               ADITYANATH
# 1109           S24            65       KU. RATANJEET PRATAP NARAYAN SINGH
# 1127           S24            66                    GORAKH PRASAD JAISWAL
# 1139           S24            67                           KAMLESH PASWAN
# 1154           S24            68                              DR. BALIRAM
# 1165           S24            69                           RAMAKANT YADAV
# 1181           S24            70                       DARA SINGH CHAUHAN
# 1197           S24            71                      RAMASHANKAR RAJBHAR
# 1222           S24            72                           NEERAJ SHEKHAR
# 1238           S24            73                          DHANANJAY SINGH
# 1254           S24            74                             TUFANI SAROJ
# 1270           S24            75                       RADHEY MOHAN SINGH
# 1285           S24            76                                RAMKISHUN
# 1303           S24            77                  DR. MURLI MANOHAR JOSHI
# 1318           S24            78                               GORAKHNATH
# 1331           S24            79                          BAL KUMAR PATEL
# 1358           S24            80                              PAKAURI LAL
#
#      Winning Party 09  Total_Electors 09  Winning Poll Percentage 09
# 0                 BSP            1298132                   63.254122
# 15                BSP            1282551                   56.587067
# 30                BSP            1370117                   54.435424
# 53                RLD            1287070                   55.017132
# 76                 SP            1196566                   53.778062
# 90                INC            1388525                   54.807007
# 108                SP            1154544                   52.503759
# 124               BSP            1290810                   52.831710
# 135               RLD            1173915                   60.224292
# 155               BJP            1508788                   48.231494
# 184               RLD            1280602                   47.934253
# 200               BJP            1831688                   45.304768
# 216               BSP            1522397                   48.544959
# 242                SP            1482749                   45.084030
# 258               BSP            1345351                   51.484334
# 281               RLD            1437725                   45.103758
# 291               RLD            1341649                   54.150899
# 307               BJP            1539683                   42.029626
# 322               BSP            1345742                   51.566125
# 336                SP            1422243                   48.156609
# 352                SP            1399259                   49.739183
# 367               IND            1278295                   44.461099
# 386                SP            1405695                   52.451492
# 396               BJP            1310878                   53.781740
# 409               INC            1401423                   50.362596
# 417               BJP            1310007                   63.964467
# 433                SP            1627964                   48.680929
# 448               INC            1297088                   54.588046
# 460               INC            1269584                   59.831409
# 472               BSP            1230078                   57.314008
# ...               ...                ...                         ...
# 825               BSP            1426450                   38.710786
# 849                SP            1267492                   43.409899
# 880               INC            1422218                   52.282210
# 895               INC            1500160                   49.939473
# 918               BSP            1494838                   54.299663
# 940               INC            1246823                   41.120592
# 953                SP            1376267                   41.100964
# 976               INC            1405884                   43.060878
# 987               INC            1341455                   45.180718
# 1012              INC            1499679                   49.216066
# 1028              BSP            1570657                   49.265498
# 1044              BSP            1694453                   47.291427
# 1068              INC            1509167                   55.631815
# 1083              BJP            1696474                   44.266815
# 1109              INC            1438263                   50.844317
# 1127              BSP            1580745                   45.398341
# 1139              BJP            1663648                   39.069022
# 1154              BSP            1509536                   43.626850
# 1165              BJP            1578854                   44.652767
# 1181              BSP            1693231                   45.230981
# 1197              BSP            1621136                   39.275113
# 1222               SP            1679029                   40.370595
# 1238              BSP            1662127                   45.969351
# 1254               SP            1751074                   40.996383
# 1270               SP            1527723                   50.431132
# 1285               SP            1446259                   46.409945
# 1303              BJP            1561854                   42.611537
# 1318              BSP            1519449                   43.386780
# 1331               SP            1405539                   52.175713
# 1358               SP            1214735                   49.295525
#
# [80 rows x 6 columns]

# %% [markdown]
# ### Import the data for 2014.

# %%
SrcDataElectors2014 = pd.read_excel("http://eci.nic.in/eci_main/StatisticalReports/candidatewise/LS-2014_ElectionResult.xls","electors", 
                                skiprows=3)
SrcDataCandidates2014 = pd.read_excel("http://eci.nic.in/eci_main/StatisticalReports/candidatewise/LS-2014_ElectionResult.xls","Cand_Wise", 
                                skiprows=3)

# %%
UPElectors2014 = SrcDataElectors2014.loc[SrcDataElectors2014.STATE == 'Uttar Pradesh',:]
UPCandidates2014 = SrcDataCandidates2014.loc[SrcDataCandidates2014["State name"]=='Uttar Pradesh',:]

# %%
temp = pd.merge(UPCandidates2014, UPElectors2014, how='outer', left_on='PC Number', right_on='PC NO')
UP2014BASEDATA = temp.loc[:,[ 'STATE CODE', 'State name', 'PC Number', 'PC name',
       'PC Type', 'Candidate Name', 'Candidate Sex', 'Candidate Category',
       'Candidate Age', 'Party Abbreviation', 'Total Votes Polled', 'Position',
       'Total voters', 'Total_Electors', 'TOT_CONTESTANT', 'POLL PERCENTAGE']]

# %%
UP2014TRAIN = pd.merge(UP2014BASEDATA,UP2009BASEDATAWINNERS, how='outer', left_on='PC Number', right_on='PC Number 09')

# %%
UP2014TRAIN = UP2014TRAIN.loc[:,['STATE CODE', 'State name', 'PC Number', 'PC name', 'PC Type',
       'Candidate Name', 'Candidate Sex', 'Candidate Category',
       'Candidate Age', 'Party Abbreviation','Total_Electors', 'TOT_CONTESTANT', 'STATE_CODE 09', 'PC Number 09', 'Winning Candidate 09',
       'Winning Party 09','Total_Electors 09', 'Winning Poll Percentage 09']]
